# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

from io import StringIO
import requests
import json
import pandas as pd

# @hidden_cell
# This function accesses a file in your Object Storage. The definition contains your credentials.
# You might want to remove those credentials before you share your notebook.
def get_object_storage_file_with_credentials_205c4f18fee14d578b3da796f1125e04(container, filename):
    """This functions returns a StringIO object containing
    the file content from Bluemix Object Storage."""

    url1 = ''.join(['https://identity.open.softlayer.com', '/v3/auth/tokens'])
    data = {'auth': {'identity': {'methods': ['password'],
            'password': {'user': {'name': 'member_cdd310eeb7086f719fbe75a724578af5086579cb','domain': {'id': 'e15e35e73d58464389fbf14d81b52f20'},
            'password': 'ws_.~Uw#64cRS_L#'}}}}}
    headers1 = {'Content-Type': 'application/json'}
    resp1 = requests.post(url=url1, data=json.dumps(data), headers=headers1)
    resp1_body = resp1.json()
    for e1 in resp1_body['token']['catalog']:
        if(e1['type']=='object-store'):
            for e2 in e1['endpoints']:
                        if(e2['interface']=='public'and e2['region']=='dallas'):
                            url2 = ''.join([e2['url'],'/', container, '/', filename])
    s_subject_token = resp1.headers['x-subject-token']
    headers2 = {'X-Auth-Token': s_subject_token, 'accept': 'application/json'}
    resp2 = requests.get(url=url2, headers=headers2)
    return StringIO(resp2.text)

df_data_1 = pd.read_csv(get_object_storage_file_with_credentials_205c4f18fee14d578b3da796f1125e04('SETI1', 'signaldb_joined_with_all_candidate_aca_events_2013_2015.csv'))
df_data_1.head(10)
# Out:
#                            UNIQUEID                 TIME         ACTTYP  \
# 0   ldn1622_1500_168_3011_19_103758  2013-03-02 06:03:29  pointantswait
# 1    ldn1622_1500_168_3002_4_103698  2013-03-02 06:03:29  pointantswait
# 2    ldn1622_1500_252_1021_3_129682  2013-03-03 05:21:45     target1-on
# 3    ldn1622_1500_252_1011_7_129839  2013-03-03 05:21:47     target1-on
# 4    ldn1622_1500_252_1015_5_129982  2013-03-03 05:21:49     target1-on
# 5    ldn1622_1500_252_1000_2_129775  2013-03-03 05:21:45     target1-on
# 6   ldn1622_1500_168_3009_18_103504  2013-03-02 06:03:28  pointantswait
# 7   kepler8ghz_33942_1002_5_1817131  2014-09-19 12:01:41         target
# 8  kepler8ghz_33942_1008_6_28843243  2014-09-19 12:01:04            NaN
# 9  kepler8ghz_33942_1002_0_28843374  2014-09-19 12:01:07            NaN
#
#      TGTID          CATALOG  RA2000HR  DEC2000DEG    POWER     SNR  \
# 0  2800031      ldn1622grid     5.872       1.087  401.000     NaN
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
plt.figure();
df_data_1['FREQMHZ'].plot.hist(bins=100)
plt.title('Start frequency of observed signal - all SignalDB')
plt.xlabel('FREQMHZ (MHz)')

# %%
plt.figure();
df_data_1['RA2000HR'].plot.hist(bins=600,xlim=(0, 24),ylim=(0, 20000))
plt.title('Right Ascension - all SignalDB')
plt.xlabel('RA2000HR (Hr)')

# %%
plt.figure();
df_data_1['DEC2000DEG'].plot.hist(bins=100,xlim=(-50, 90))

# %%
plt.figure();
df_data_1['POWER'].plot()#ylim=(0, 100000))#.hist(bins=400,xlim=(0, 5000))

# %%
plt.figure();
df_data_1['WIDHZ'].plot.hist(bins=100,ylim=(0, 1500))
plt.title('Signal Bandwidth - all SignalDB')
plt.xlabel('WIDHZ (Hz)')

# %%
plt.figure();
df_data_1['DRIFTHZS'].plot.hist(bins=100)#,ylim=(0, 1500))
plt.title('Signal Drift - all SignalDB')
plt.xlabel('DRIFTHZS (Hz/s)')

# %%
plt.figure();
df_data_1['SNR'].plot.hist(bins=100)#,ylim=(0, 1500))
plt.title('Signal/Noise Ratio - all SignalDB')
plt.xlabel('SNR')

# %%
plt.figure();
df_data_1['NPUL'].plot.hist(bins=200,xlim=(0, 100),ylim=(0, 20000))
plt.title('Number of pulses - all SignalDB')
plt.xlabel('NPUL')

# %%
plt.figure();
df_data_1['PPERIODS'].plot.hist(bins=100,ylim=(0, 8000))#,ylim=(0, 20000))
plt.title('Pulse Period - all SignalDB')
plt.xlabel('PPERIODS (s)')

# %%
plt.figure();
df_data_1['BEAMNO'].plot.hist(bins=3)#,xlim=(0, 100),ylim=(0, 20000))
plt.title('Beam signal number - all SignalDB')
plt.xlabel('BEAMNO')

# %%
plt.figure();
df_data_1['TSCPELDEG'].plot.hist(bins=100,ylim=(0, 15000))
plt.title('Primary telescope elevation direction - all SignalDB')
plt.xlabel('TSCPELDEG (deg)')

# %%
plt.figure();
df_data_1['TSCPAZDEG'].plot.hist(bins=100,ylim=(0, 40000))
plt.title('Primary telescope azimuth direction - all SignalDB')
plt.xlabel('TSCPAZDEG (deg)')

# %%
plt.figure();
df_data_1['CATALOG'].apply(pd.value_counts).plot.bar()
plt.title('Target catalog name - all SignalDB')
plt.xlabel('CATALOG')
# Out:
# MemoryErrorTraceback (most recent call last)
# <ipython-input-75-172e9bf09fb3> in <module>()
#       1 plt.figure();
# ----> 2 df_data_1['CATALOG'].apply(pd.value_counts).plot.bar()
#       3 plt.title('Target catalog name - all SignalDB')
#       4 plt.xlabel('CATALOG')
#
# /usr/local/src/bluemix_jupyter_bundle.v43/notebook/lib/python2.7/site-packages/pandas/tools/plotting.pyc in bar(self, x, y, **kwds)
#    3708         axes : matplotlib.AxesSubplot or np.array of them
#    3709         """
# -> 3710         return self(kind='bar', x=x, y=y, **kwds)
#    3711
#    3712     def barh(self, x=None, y=None, **kwds):
#
# /usr/local/src/bluemix_jupyter_bundle.v43/notebook/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...
