# %% [markdown]
# # IBM SETI Tutorial
#
# Full documentation can be found here: https://github.com/ibm-cds-labs/seti_at_ibm/blob/master/setigopublic.md

# %%
import requests

# %% [markdown]
# ## Search For Data
#
# GET `/v1/coordinates/aca`
#
# #### Interesting Target
#
# Kepler 1229b, found here http://phl.upr.edu/projects/habitable-exoplanets-catalog, is a very intersting target. This candidate has an Earth similarity index (ESI) of 0.73 (Earth = 1.0, Mars = 0.64, Jupiter = 0.12)
# and is 770 light-years away. It is the 5th highest-ranked planet by ESI. According to the catalog, it's RA/DEC coordinates are 19.832 and 46.997, respectively.
#
# Search the `/v1/coordinates/aca` endpoint of the public `https://setigopublic.mybluemix.net` data server to see if we have data for that location.
#
# Using the URL parameters, `ramin`, `ramax`, `decmin` and `decmax` for that endpoint, we define a box in the sky around that target and make our query. This ensures we find any data in the direction of the object -- allowing for a small range about its exact location.

# %%
RA=19.832
DEC=46.997
box = 0.002

# %%
params = {
'ramin':RA-box, 'ramax':RA+box, 'decmin':DEC-box, 'decmax':DEC+box
}
r = requests.get('https://setigopublic.mybluemix.net/v1/coordinates/aca',
  params = params)

r.raise_for_status()

import json
print json.dumps(r.json(), indent=1)
# Out:
# {
#  "returned_num_rows": 1,
#  "skipped_num_rows": 0,
#  "rows": [
#   {
#    "dec2000deg": 46.997,
#    "number_of_candidates": 392,
#    "ra2000hr": 19.832
#   }
#  ],
#  "total_num_rows": 1
# }

# %% [markdown]
# ### SignalDB Data
#
# GET `/v1/aca/meta/{ra}/{dec}`
#
# We now know that data exists for this target. There are 392 "rows". This means there were 392 candidate signals found in the raw data and entered as a row in the SignalDB. But this doesn't necessarily mean there are 392 data files since the SignalDB may contain multiple rows from the same raw data source. We can obtain the SignalDB data and raw data locations for each of these rows with the `/v1/aca/meta/{ra}/{dec}` endpoint.

# %%
ra = r.json()['rows'][0]['ra2000hr']
dec = r.json()['rows'][0]['dec2000deg']

r = requests.get('https://setigopublic.mybluemix.net/v1/aca/meta/{}/{}'.format(ra,dec))

r.raise_for_status()

print json.dumps(r.json(), indent=1)
# Out:
# {
#  "returned_num_rows": 200,
#  "skipped_num_rows": 0,
#  "rows": [
#   {
#    "inttimes": 94,
#    "pperiods": 27.36000061,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 6113.461883333,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14944/2014-05-20_13-00-01_UTC.act14944.dx2016.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 50.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.397,
#    "uniqueid": "kepler8ghz_14944_2016_0_2208930",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.558,
#    "drifthzs": -1.055,
#    "candreason": "Confrm",
#    "time": "2014-05-20T12:59:55Z",
#    "tscpazdeg": 307.339
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 27.36000061,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 6113.461883333,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14944/2014-05-20_13-00-01_UTC.act14944.dx2016.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 50.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.397,
#    "uniqueid": "kepler8ghz_14944_2016_0_2208930",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.558,
#    "drifthzs": -1.055,
#    "candreason": "Confrm",
#    "time": "2014-05-20T12:59:55Z",
#    "tscpazdeg": 307.339
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 27.36000061,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6113.461883333,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14944/2014-05-20_13-00-01_UTC.act14944.dx2016.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 50.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.397,
#    "uniqueid": "kepler8ghz_14944_2016_0_726717",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.558,
#    "drifthzs": -1.055,
#    "candreason": "Confrm",
#    "time": "2014-05-20T13:00:01Z",
#    "tscpazdeg": 307.339
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 27.36000061,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6113.461883333,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14944/2014-05-20_13-00-01_UTC.act14944.dx2016.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 50.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.397,
#    "uniqueid": "kepler8ghz_14944_2016_0_726717",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.558,
#    "drifthzs": -1.055,
#    "candreason": "Confrm",
#    "time": "2014-05-20T13:00:01Z",
#    "tscpazdeg": 307.339
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 36.900001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 6148.490366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14947/2014-05-20_13-08-35_UTC.act14947.dx2013.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 64.785,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.214,
#    "uniqueid": "kepler8ghz_14947_2013_0_2209059",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 77.25,
#    "drifthzs": 1.326,
#    "candreason": "Confrm",
#    "time": "2014-05-20T13:08:33Z",
#    "tscpazdeg": 304.323
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 36.900001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 6148.490366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14947/2014-05-20_13-08-35_UTC.act14947.dx2013.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 64.785,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.214,
#    "uniqueid": "kepler8ghz_14947_2013_0_2209059",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 77.25,
#    "drifthzs": 1.326,
#    "candreason": "Confrm",
#    "time": "2014-05-20T13:08:33Z",
#    "tscpazdeg": 304.323
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 36.900001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6148.490366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14947/2014-05-20_13-08-35_UTC.act14947.dx2013.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 64.785,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.214,
#    "uniqueid": "kepler8ghz_14947_2013_0_726822",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 77.25,
#    "drifthzs": 1.326,
#    "candreason": "Confrm",
#    "time": "2014-05-20T13:08:35Z",
#    "tscpazdeg": 304.323
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 36.900001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6148.490366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-20/act14947/2014-05-20_13-08-35_UTC.act14947.dx2013.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 64.785,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.214,
#    "uniqueid": "kepler8ghz_14947_2013_0_726822",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 77.25,
#    "drifthzs": 1.326,
#    "candreason": "Confrm",
#    "time": "2014-05-20T13:08:35Z",
#    "tscpazdeg": 304.323
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 20.880001068,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6032.863361111,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-25/act15742/2014-05-25_12-39-45_UTC.act15742.dx2017.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 55.841,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 36,
#    "uniqueid": "kepler8ghz_15742_2017_0_752199",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 0.995,
#    "candreason": "Confrm",
#    "time": "2014-05-25T12:39:45Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 20.880001068,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6032.863361111,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-25/act15742/2014-05-25_12-39-45_UTC.act15742.dx2017.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 55.841,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 36,
#    "uniqueid": "kepler8ghz_15742_2017_0_752199",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 0.995,
#    "candreason": "Confrm",
#    "time": "2014-05-25T12:39:45Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 17.820001602,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6064.549580555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-25/act15745/2014-05-25_12-48-25_UTC.act15745.dx2009.id-1.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 64.015,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.786,
#    "uniqueid": "kepler8ghz_15745_2009_1_752234",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -2.863,
#    "candreason": "Confrm",
#    "time": "2014-05-25T12:48:24Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 17.820001602,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 6064.549580555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-25/act15745/2014-05-25_12-48-25_UTC.act15745.dx2009.id-1.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 64.015,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.786,
#    "uniqueid": "kepler8ghz_15745_2009_1_752234",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -2.863,
#    "candreason": "Confrm",
#    "time": "2014-05-25T12:48:24Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 37.080001831,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5947.787452777,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16577/2014-05-29_12-24-36_UTC.act16577.dx2012.id-1.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 51.406,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.921,
#    "uniqueid": "kepler8ghz_16577_2012_1_775018",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -5.666,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:24:36Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 37.080001831,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5947.787452777,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16577/2014-05-29_12-24-36_UTC.act16577.dx2012.id-1.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 51.406,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.921,
#    "uniqueid": "kepler8ghz_16577_2012_1_775018",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -5.666,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:24:36Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.740001678,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5974.78991111,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16578/2014-05-29_12-27-27_UTC.act16578.dx2022.id-1.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 67.212,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.562,
#    "uniqueid": "kepler8ghz_16578_2022_1_775056",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -5.546,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:27:27Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.740001678,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5974.78991111,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16578/2014-05-29_12-27-27_UTC.act16578.dx2022.id-1.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 67.212,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.562,
#    "uniqueid": "kepler8ghz_16578_2022_1_775056",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -5.546,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:27:27Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 16.920000076,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5974.920080555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16578/2014-05-29_12-27-27_UTC.act16578.dx2022.id-3.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 51.894,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.26,
#    "uniqueid": "kepler8ghz_16578_2022_3_775057",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -4.461,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:27:27Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 16.920000076,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5974.920080555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16578/2014-05-29_12-27-27_UTC.act16578.dx2022.id-3.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 51.894,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.26,
#    "uniqueid": "kepler8ghz_16578_2022_3_775057",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -4.461,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:27:27Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 20.520000458,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5980.101727776,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16581/2014-05-29_12-36-03_UTC.act16581.dx2005.id-10.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 68.971,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.54,
#    "uniqueid": "kepler8ghz_16581_2005_10_775135",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -2.291,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:36:03Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 20.520000458,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5980.101727776,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16581/2014-05-29_12-36-03_UTC.act16581.dx2005.id-10.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 68.971,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.54,
#    "uniqueid": "kepler8ghz_16581_2005_10_775135",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -2.291,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:36:03Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 40.5,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5980.927280554,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16581/2014-05-29_12-36-03_UTC.act16581.dx2006.id-2.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 52.06,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.375,
#    "uniqueid": "kepler8ghz_16581_2006_2_775119",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -4.19,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:36:03Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 40.5,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5980.927280554,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16581/2014-05-29_12-36-03_UTC.act16581.dx2006.id-2.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 52.06,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.375,
#    "uniqueid": "kepler8ghz_16581_2006_2_775119",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -4.19,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:36:03Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 26.280000687,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5992.993841665,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16581/2014-05-29_12-36-03_UTC.act16581.dx2021.id-12.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 50.689,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.423,
#    "uniqueid": "kepler8ghz_16581_2021_12_775151",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 3.195,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:36:03Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 26.280000687,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5992.993841665,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-05-29/act16581/2014-05-29_12-36-03_UTC.act16581.dx2021.id-12.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 50.689,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.423,
#    "uniqueid": "kepler8ghz_16581_2021_12_775151",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 3.195,
#    "candreason": "Confrm",
#    "time": "2014-05-29T12:36:03Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.520000458,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5811.789472222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-03/act17129/2014-06-03_11-56-36_UTC.act17129.dx2014.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 50.926,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.587,
#    "uniqueid": "kepler8ghz_17129_2014_0_789737",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -1.115,
#    "candreason": "Confrm",
#    "time": "2014-06-03T11:56:36Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.520000458,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5811.789472222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-03/act17129/2014-06-03_11-56-36_UTC.act17129.dx2014.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 50.926,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.587,
#    "uniqueid": "kepler8ghz_17129_2014_0_789737",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -1.115,
#    "candreason": "Confrm",
#    "time": "2014-06-03T11:56:36Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 13.140000343,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5814.947188889,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-03/act17129/2014-06-03_11-56-36_UTC.act17129.dx2018.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 74.137,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 38.41,
#    "uniqueid": "kepler8ghz_17129_2018_0_789738",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 3.074,
#    "candreason": "Confrm",
#    "time": "2014-06-03T11:56:36Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 13.140000343,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5814.947188889,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-03/act17129/2014-06-03_11-56-36_UTC.act17129.dx2018.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 74.137,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 38.41,
#    "uniqueid": "kepler8ghz_17129_2018_0_789738",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 3.074,
#    "candreason": "Confrm",
#    "time": "2014-06-03T11:56:36Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 32.400001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5649.063566666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-11/act18279/2014-06-11_10-18-46_UTC.act18279.dx2013.id-2.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 63.672,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.596,
#    "uniqueid": "kepler8ghz_18279_2013_2_3681682",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 82.693,
#    "drifthzs": 3.918,
#    "candreason": "Confrm",
#    "time": "2014-06-11T10:18:40Z",
#    "tscpazdeg": 29.949
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 32.400001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5649.063566666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-11/act18279/2014-06-11_10-18-46_UTC.act18279.dx2013.id-2.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 63.672,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.596,
#    "uniqueid": "kepler8ghz_18279_2013_2_3681682",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 82.693,
#    "drifthzs": 3.918,
#    "candreason": "Confrm",
#    "time": "2014-06-11T10:18:40Z",
#    "tscpazdeg": 29.949
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 32.400001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5649.063566666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-11/act18279/2014-06-11_10-18-46_UTC.act18279.dx2013.id-2.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 63.672,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.596,
#    "uniqueid": "kepler8ghz_18279_2013_2_854706",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 3.918,
#    "candreason": "Confrm",
#    "time": "2014-06-11T10:18:46Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 32.400001526,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5649.063566666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-11/act18279/2014-06-11_10-18-46_UTC.act18279.dx2013.id-2.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 63.672,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.596,
#    "uniqueid": "kepler8ghz_18279_2013_2_854706",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 3.918,
#    "candreason": "Confrm",
#    "time": "2014-06-11T10:18:46Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.380001068,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5532.757541666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18678/2014-06-13_11-18-05_UTC.act18678.dx2016.id-1.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 64.714,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.175,
#    "uniqueid": "kepler8ghz_18678_2016_1_3698254",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 79.666,
#    "drifthzs": -4.792,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:18:01Z",
#    "tscpazdeg": 310.789
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.380001068,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5532.757541666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18678/2014-06-13_11-18-05_UTC.act18678.dx2016.id-1.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 64.714,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.175,
#    "uniqueid": "kepler8ghz_18678_2016_1_3698254",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 79.666,
#    "drifthzs": -4.792,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:18:01Z",
#    "tscpazdeg": 310.789
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.380001068,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5532.757541666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18678/2014-06-13_11-18-05_UTC.act18678.dx2016.id-1.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 64.714,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.175,
#    "uniqueid": "kepler8ghz_18678_2016_1_868801",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -4.792,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:18:05Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.380001068,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5532.757541666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18678/2014-06-13_11-18-05_UTC.act18678.dx2016.id-1.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 64.714,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.175,
#    "uniqueid": "kepler8ghz_18678_2016_1_868801",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -4.792,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:18:05Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 25.200000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5571.419491666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2018.id-2.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 54.983,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.405,
#    "uniqueid": "kepler8ghz_18681_2018_2_3698510",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.409,
#    "drifthzs": -3.014,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:39Z",
#    "tscpazdeg": 306.957
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 25.200000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5571.419491666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2018.id-2.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 54.983,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.405,
#    "uniqueid": "kepler8ghz_18681_2018_2_3698510",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.409,
#    "drifthzs": -3.014,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:39Z",
#    "tscpazdeg": 306.957
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 25.200000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5571.419491666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2018.id-2.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 54.983,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.405,
#    "uniqueid": "kepler8ghz_18681_2018_2_868958",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -3.014,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:48Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 25.200000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5571.419491666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2018.id-2.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 54.983,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.405,
#    "uniqueid": "kepler8ghz_18681_2018_2_868958",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -3.014,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:48Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 13.680000305,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5573.72813611,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2021.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 52.809,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.895,
#    "uniqueid": "kepler8ghz_18681_2021_0_3698522",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.409,
#    "drifthzs": 1.718,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:40Z",
#    "tscpazdeg": 306.957
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 13.680000305,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5573.72813611,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2021.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 52.809,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.895,
#    "uniqueid": "kepler8ghz_18681_2021_0_3698522",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 78.409,
#    "drifthzs": 1.718,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:40Z",
#    "tscpazdeg": 306.957
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 13.680000305,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5573.72813611,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2021.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 52.809,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.895,
#    "uniqueid": "kepler8ghz_18681_2021_0_868961",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.718,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:48Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 13.680000305,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5573.72813611,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-13/act18681/2014-06-13_11-26-48_UTC.act18681.dx2021.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 52.809,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 33.895,
#    "uniqueid": "kepler8ghz_18681_2021_0_868961",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.718,
#    "candreason": "Confrm",
#    "time": "2014-06-13T11:26:48Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.560001373,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5333.645644444,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-21/act19776/2014-06-21_10-33-46_UTC.act19776.dx2018.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 53.408,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.311,
#    "uniqueid": "kepler8ghz_19776_2018_0_3734554",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 81.415,
#    "drifthzs": 1.959,
#    "candreason": "Confrm",
#    "time": "2014-06-21T10:33:39Z",
#    "tscpazdeg": 319.128
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.560001373,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5333.645644444,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-21/act19776/2014-06-21_10-33-46_UTC.act19776.dx2018.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 53.408,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.311,
#    "uniqueid": "kepler8ghz_19776_2018_0_3734554",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 81.415,
#    "drifthzs": 1.959,
#    "candreason": "Confrm",
#    "time": "2014-06-21T10:33:39Z",
#    "tscpazdeg": 319.128
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.560001373,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5333.645644444,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-21/act19776/2014-06-21_10-33-46_UTC.act19776.dx2018.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 53.408,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.311,
#    "uniqueid": "kepler8ghz_19776_2018_0_897467",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.959,
#    "candreason": "Confrm",
#    "time": "2014-06-21T10:33:46Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 34.560001373,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5333.645644444,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-21/act19776/2014-06-21_10-33-46_UTC.act19776.dx2018.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 53.408,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.311,
#    "uniqueid": "kepler8ghz_19776_2018_0_897467",
#    "beamno": 2,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.959,
#    "candreason": "Confrm",
#    "time": "2014-06-21T10:33:46Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 38.520000458,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5000.285366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-29/act20769/2014-06-29_10-18-19_UTC.act20769.dx1050.id-3.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 53.061,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 46.353,
#    "uniqueid": "kepler8ghz_20769_1050_3_3843454",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 79.219,
#    "drifthzs": 0.211,
#    "candreason": "Confrm",
#    "time": "2014-06-29T10:18:13Z",
#    "tscpazdeg": 309.292
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 38.520000458,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 5000.285366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-29/act20769/2014-06-29_10-18-19_UTC.act20769.dx1050.id-3.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 53.061,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 46.353,
#    "uniqueid": "kepler8ghz_20769_1050_3_3843454",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 79.219,
#    "drifthzs": 0.211,
#    "candreason": "Confrm",
#    "time": "2014-06-29T10:18:13Z",
#    "tscpazdeg": 309.292
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 38.520000458,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5000.285366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-29/act20769/2014-06-29_10-18-19_UTC.act20769.dx1050.id-3.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 53.061,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 46.353,
#    "uniqueid": "kepler8ghz_20769_1050_3_978558",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 79.219,
#    "drifthzs": 0.211,
#    "candreason": "Confrm",
#    "time": "2014-06-29T10:18:19Z",
#    "tscpazdeg": 309.292
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 38.520000458,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 5000.285366666,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-06-29/act20769/2014-06-29_10-18-19_UTC.act20769.dx1050.id-3.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 53.061,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 46.353,
#    "uniqueid": "kepler8ghz_20769_1050_3_978558",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 79.219,
#    "drifthzs": 0.211,
#    "candreason": "Confrm",
#    "time": "2014-06-29T10:18:19Z",
#    "tscpazdeg": 309.292
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.160001755,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4695.431163887,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-06/act22041/2014-07-06_09-26-38_UTC.act22041.dx1021.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 73.092,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 37.829,
#    "uniqueid": "kepler8ghz_22041_1021_0_1150131",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 82.351,
#    "drifthzs": -0.543,
#    "candreason": "Confrm",
#    "time": "2014-07-06T09:26:38Z",
#    "tscpazdeg": 326.409
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.160001755,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4695.431163887,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-06/act22041/2014-07-06_09-26-38_UTC.act22041.dx1021.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 73.092,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 37.829,
#    "uniqueid": "kepler8ghz_22041_1021_0_1150131",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 82.351,
#    "drifthzs": -0.543,
#    "candreason": "Confrm",
#    "time": "2014-07-06T09:26:38Z",
#    "tscpazdeg": 326.409
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.160001755,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4695.431163887,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-06/act22041/2014-07-06_09-26-38_UTC.act22041.dx1021.id-0.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 73.092,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 37.829,
#    "uniqueid": "kepler8ghz_22041_1021_0_4207269",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 82.351,
#    "drifthzs": -0.543,
#    "candreason": "Confrm",
#    "time": "2014-07-06T09:26:21Z",
#    "tscpazdeg": 326.409
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.160001755,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4695.431163887,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-06/act22041/2014-07-06_09-26-38_UTC.act22041.dx1021.id-0.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 73.092,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 37.829,
#    "uniqueid": "kepler8ghz_22041_1021_0_4207269",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 82.351,
#    "drifthzs": -0.543,
#    "candreason": "Confrm",
#    "time": "2014-07-06T09:26:21Z",
#    "tscpazdeg": 326.409
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "both",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4137.049072299,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1003.id-100.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": "target",
#    "power": 72.96,
#    "widhz": 0.174,
#    "catalog": "keplerHZ",
#    "snr": 0.222,
#    "uniqueid": "kepler8ghz_22876_1003_100_1211951",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwC",
#    "tscpeldeg": 83.762,
#    "drifthzs": -0.05,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:14Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "both",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4137.049072299,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1003.id-100.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": "target",
#    "power": 72.96,
#    "widhz": 0.174,
#    "catalog": "keplerHZ",
#    "snr": 0.222,
#    "uniqueid": "kepler8ghz_22876_1003_100_1211951",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwC",
#    "tscpeldeg": 83.762,
#    "drifthzs": -0.05,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:14Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4137.04907499,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1003.id-100.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": null,
#    "power": 415,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": null,
#    "uniqueid": "kepler8ghz_22876_1003_100_6170919",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwP",
#    "tscpeldeg": 83.762,
#    "drifthzs": -0.06,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:00Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4137.04907499,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1003.id-100.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": null,
#    "power": 415,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": null,
#    "uniqueid": "kepler8ghz_22876_1003_100_6170919",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwP",
#    "tscpeldeg": 83.762,
#    "drifthzs": -0.06,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:00Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "both",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4143.040763162,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1010.id-71.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": "target",
#    "power": 41.295,
#    "widhz": 0.022,
#    "catalog": "keplerHZ",
#    "snr": 0.202,
#    "uniqueid": "kepler8ghz_22876_1010_71_1211593",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwC",
#    "tscpeldeg": 0,
#    "drifthzs": 0.024,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:14Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "both",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4143.040763162,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1010.id-71.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": "target",
#    "power": 41.295,
#    "widhz": 0.022,
#    "catalog": "keplerHZ",
#    "snr": 0.202,
#    "uniqueid": "kepler8ghz_22876_1010_71_1211593",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwC",
#    "tscpeldeg": 0,
#    "drifthzs": 0.024,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:14Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4143.040761101,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1010.id-71.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": null,
#    "power": 413,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": null,
#    "uniqueid": "kepler8ghz_22876_1010_71_6160128",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwP",
#    "tscpeldeg": 83.762,
#    "drifthzs": 0.03,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:36:51Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4143.040761101,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1010.id-71.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": null,
#    "power": 413,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": null,
#    "uniqueid": "kepler8ghz_22876_1010_71_6160128",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwP",
#    "tscpeldeg": 83.762,
#    "drifthzs": 0.03,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:36:51Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "both",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4148.452883497,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1017.id-63.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": "target",
#    "power": 106.989,
#    "widhz": 0.347,
#    "catalog": "keplerHZ",
#    "snr": 0.233,
#    "uniqueid": "kepler8ghz_22876_1017_63_1211925",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwC",
#    "tscpeldeg": 0,
#    "drifthzs": -0.097,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:14Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "both",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 4148.452883497,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1017.id-63.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": "target",
#    "power": 106.989,
#    "widhz": 0.347,
#    "catalog": "keplerHZ",
#    "snr": 0.233,
#    "uniqueid": "kepler8ghz_22876_1017_63_1211925",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwC",
#    "tscpeldeg": 0,
#    "drifthzs": -0.097,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:14Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "right",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4148.452886101,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-13/act22876/2014-07-13_08-37-14_UTC.act22876.dx1017.id-63.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": null,
#    "acttype": null,
#    "power": 410,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": null,
#    "uniqueid": "kepler8ghz_22876_1017_63_6170692",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "CwP",
#    "tscpeldeg": 83.762,
#    "drifthzs": -0.09,
#    "candreason": "Confrm",
#    "time": "2014-07-13T08:37:00Z",
#    "tscpazdeg": 355.847
#   },
#   {
#    "inttimes": 94,
#    "pperiods": null,
#    "pol": "right",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 4148.452886101,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
# ...
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 46.198,
#    "drifthzs": 0.723,
#    "candreason": "Confrm",
#    "time": "2014-07-31T11:30:26Z",
#    "tscpazdeg": 299.771
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 7.56000042,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3588.111216665,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-31/act25712/2014-07-31_11-30-26_UTC.act25712.dx1005.id-9.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 55.579,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.819,
#    "uniqueid": "kepler8ghz_25712_1005_9_17839426",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 46.198,
#    "drifthzs": 0.723,
#    "candreason": "Confrm",
#    "time": "2014-07-31T11:30:21Z",
#    "tscpazdeg": 299.771
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 7.56000042,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3588.111216665,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-07-31/act25712/2014-07-31_11-30-26_UTC.act25712.dx1005.id-9.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 55.579,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 35.819,
#    "uniqueid": "kepler8ghz_25712_1005_9_17839426",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 46.198,
#    "drifthzs": 0.723,
#    "candreason": "Confrm",
#    "time": "2014-07-31T11:30:21Z",
#    "tscpazdeg": 299.771
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3410.449597222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1002.id-17.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": "target",
#    "power": 75.935,
#    "widhz": 63.889,
#    "catalog": "keplerHZ",
#    "snr": 39.408,
#    "uniqueid": "kepler8ghz_26132_1002_17_1399777",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -0.151,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:25Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3410.449597222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1002.id-17.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": "target",
#    "power": 75.935,
#    "widhz": 63.889,
#    "catalog": "keplerHZ",
#    "snr": 39.408,
#    "uniqueid": "kepler8ghz_26132_1002_17_1399777",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -0.151,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:25Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3410.449597222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1002.id-17.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": null,
#    "power": 75.935,
#    "widhz": 63.889,
#    "catalog": "keplerHZ",
#    "snr": 39.408,
#    "uniqueid": "kepler8ghz_26132_1002_17_17996077",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.327,
#    "drifthzs": -0.151,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:15Z",
#    "tscpazdeg": 339.842
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3410.449597222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1002.id-17.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": null,
#    "power": 75.935,
#    "widhz": 63.889,
#    "catalog": "keplerHZ",
#    "snr": 39.408,
#    "uniqueid": "kepler8ghz_26132_1002_17_17996077",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.327,
#    "drifthzs": -0.151,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:15Z",
#    "tscpazdeg": 339.842
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.25999999,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3422.225572222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1017.id-8.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 51.164,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.753,
#    "uniqueid": "kepler8ghz_26132_1017_8_1399792",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:25Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.25999999,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3422.225572222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1017.id-8.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 51.164,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.753,
#    "uniqueid": "kepler8ghz_26132_1017_8_1399792",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:25Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.25999999,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3422.225572222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1017.id-8.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 51.164,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.753,
#    "uniqueid": "kepler8ghz_26132_1017_8_17996210",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.327,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:17Z",
#    "tscpazdeg": 339.842
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.25999999,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3422.225572222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1017.id-8.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 51.164,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 32.753,
#    "uniqueid": "kepler8ghz_26132_1017_8_17996210",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.327,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:17Z",
#    "tscpazdeg": 339.842
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3425.655963889,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1021.id-23.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": "target",
#    "power": 66.267,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 43.241,
#    "uniqueid": "kepler8ghz_26132_1021_23_1399798",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:25Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3425.655963889,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1021.id-23.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": "target",
#    "power": 66.267,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 43.241,
#    "uniqueid": "kepler8ghz_26132_1021_23_1399798",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:25Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3425.655963889,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1021.id-23.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": null,
#    "power": 66.267,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 43.241,
#    "uniqueid": "kepler8ghz_26132_1021_23_17996287",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.327,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:17Z",
#    "tscpazdeg": 339.842
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 1.080000043,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3425.655963889,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26132/2014-08-03_07-25-25_UTC.act26132.dx1021.id-23.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 4,
#    "acttype": null,
#    "power": 66.267,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 43.241,
#    "uniqueid": "kepler8ghz_26132_1021_23_17996287",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.327,
#    "drifthzs": 1.085,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:25:17Z",
#    "tscpazdeg": 339.842
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 7.740000248,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3438.215797222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26133/2014-08-03_07-28-39_UTC.act26133.dx1013.id-30.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 52.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 45.974,
#    "uniqueid": "kepler8ghz_26133_1013_30_1399930",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -0.874,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:28:38Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 7.740000248,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3438.215797222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26133/2014-08-03_07-28-39_UTC.act26133.dx1013.id-30.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 52.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 45.974,
#    "uniqueid": "kepler8ghz_26133_1013_30_1399930",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 0,
#    "drifthzs": -0.874,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:28:38Z",
#    "tscpazdeg": 0
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 7.740000248,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3438.215797222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26133/2014-08-03_07-28-39_UTC.act26133.dx1013.id-30.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 52.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 45.974,
#    "uniqueid": "kepler8ghz_26133_1013_30_17996496",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.083,
#    "drifthzs": -0.874,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:28:30Z",
#    "tscpazdeg": 335.467
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 7.740000248,
#    "pol": "left",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3438.215797222,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26133/2014-08-03_07-28-39_UTC.act26133.dx1013.id-30.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 52.652,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 45.974,
#    "uniqueid": "kepler8ghz_26133_1013_30_17996496",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 83.083,
#    "drifthzs": -0.874,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:28:30Z",
#    "tscpazdeg": 335.467
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.700000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3476.619455555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26137/2014-08-03_07-42-12_UTC.act26137.dx1014.id-13.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 54.147,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.824,
#    "uniqueid": "kepler8ghz_26137_1014_13_1400013",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 81.727,
#    "drifthzs": -0.512,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:42:12Z",
#    "tscpazdeg": 321.275
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.700000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "Confrm",
#    "freqmhz": 3476.619455555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26137/2014-08-03_07-42-12_UTC.act26137.dx1014.id-13.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": "target",
#    "power": 54.147,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.824,
#    "uniqueid": "kepler8ghz_26137_1014_13_1400013",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 81.727,
#    "drifthzs": -0.512,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:42:12Z",
#    "tscpazdeg": 321.275
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.700000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3476.619455555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26137/2014-08-03_07-42-12_UTC.act26137.dx1014.id-13.L.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 54.147,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.824,
#    "uniqueid": "kepler8ghz_26137_1014_13_17998313",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 81.727,
#    "drifthzs": -0.512,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:42:05Z",
#    "tscpazdeg": 321.275
#   },
#   {
#    "inttimes": 94,
#    "pperiods": 29.700000763,
#    "pol": "mixed",
#    "tgtid": 150096,
#    "sigreason": "PsPwrT",
#    "freqmhz": 3476.619455555,
#    "dec2000deg": 46.997,
#    "container": "setiCompAmp",
#    "objectname": "2014-08-03/act26137/2014-08-03_07-42-12_UTC.act26137.dx1014.id-13.R.archive-compamp",
#    "ra2000hr": 19.832,
#    "npul": 3,
#    "acttype": null,
#    "power": 54.147,
#    "widhz": 2.778,
#    "catalog": "keplerHZ",
#    "snr": 34.824,
#    "uniqueid": "kepler8ghz_26137_1014_13_17998313",
#    "beamno": 1,
#    "sigclass": "Cand",
#    "sigtyp": "Pul",
#    "tscpeldeg": 81.727,
#    "drifthzs": -0.512,
#    "candreason": "Confrm",
#    "time": "2014-08-03T07:42:05Z",
#    "tscpazdeg": 321.275
#   }
#  ],
#  "total_num_rows": 392
# }

# %% [markdown]
# ##### r.json()
#
# This is the SignalDB data along with the path to the raw data file (container, objectname)
# By default only returns 200 rows, but can use `skip` keyword in request params to page through results.
# You can also increase the number of rows returned by setting `limit=2000` (2000 is the maximum) and paginate through with `skip`.
#
#     {
#      "returned_num_rows": 200,
#      "skipped_num_rows": 0,
#      "rows": [
#       {
#        "inttimes": 94,
#        "pperiods": 27.36000061,
#        "pol": "mixed",
#        "tgtid": 150096,
#        "sigreason": "PsPwrT",
#        "freqmhz": 6113.461883333,
#        "dec2000deg": 46.997,
#        "container": "setiCompAmp",
#        "objectname": "2014-05-20/act14944/2014-05-20_13-00-01_UTC.act14944.dx2016.id-0.L.archive-compamp",
#        "ra2000hr": 19.832,
#        "npul": 3,
#        "acttype": null,
#        "power": 50.652,
#        "widhz": 2.778,
#        "catalog": "keplerHZ",
#        "snr": 32.397,
#        "uniqueid": "kepler8ghz_14944_2016_0_2208930",
#        "beamno": 2,
#        "sigclass": "Cand",
#        "sigtyp": "Pul",
#        "tscpeldeg": 78.558,
#        "drifthzs": -1.055,
#        "candreason": "Confrm",
#        "time": "2014-05-20T12:59:55Z",
#        "tscpazdeg": 307.339
#       },
#
#       ...
#
#       "total_num_rows": 392
#     }

# %% [markdown]
# #### SignalDB Analysis
#
# There are many things to explore with the SignalDB data. You don't need to access the raw data (in the next step) in order to start visualizing and analyzing SETI data.
#
# There is no limit to how much SignalDB data you can consume! So, please feel free to pull down as much as you can. It would be interesting to see a density plot of Candidate signals and "candreason"/"sigreason" versus position in the sky, the distribution of carrier wave signal frequencies (freqmhz), drift rates, and signal types for each RA/DEC position, etc. There are lots of plots to be generated from these data alone.

# %% [markdown]
# ## Raw Signal Data
#
# GET `/v1/data/url/{containter}/{objectname}`
#
# The JSON returned above contains the **container** and **objectname** of the ACA file in our Object Store service. We can retrieve the data with an HTTP request.
#
# We use the `/v1/data/url/{container}/{objectname}` endpoint to obtain a temporary URL to the data store in Object Store. This temporary URL is valid only for 24 hours. Each Bluemix user will be alloted 20,000 temporary URLs per month. If you need more, however, send us a message and we can grant you more access.
#
# ### Access Token
#
# For this HTTP endpoint only, you must supply a token. This requires you to have an IBM DSX account. In addition, this endpoint has a rate limit of 20,000 requests per month. (However, if you
# <a href="https://github.com/ibm-cds-labs/seti_at_ibm/blob/master/contact_us.md" target="_blank">make a compelling argument</a> for your analysis, this limit can be increased without a problem.)
#
# 1. Click on the following link: <a href="https://setigopublic.mybluemix.net/token" target="_blank">https://setigopublic.mybluemix.net/token</a> (opens a new tab).
#
# 2. Login to DSX/Bluemix.
#
# 3. Copy the value of the token into the `params` object below. It is passed as a query parameter.
#
# 4. Use this token for all future requests to the `/v1/data/url/{container}/{objectname}` endpoint.

# %%
params = {'access_token':'9798b5d71b649b36d5307919940372e7'}

# %%
#Get Temporary URL for the first object
cont = r.json()['rows'][10]['container']
objname = r.json()['rows'][10]['objectname']

base_url = 'https://setigopublic.mybluemix.net/v1/data/url'  #this HTTP API returns a temporary URL for the container/objectname
r = requests.get('/'.join([base_url, cont, objname]), params=params)
r.raise_for_status()

tmp_url = r.json()['temp_url']
print 'URL:', tmp_url

r_data = requests.get(tmp_url)
r_data.raise_for_status()

rawdata = r_data.content
print 'file size: ', len(rawdata)
# Out:
# URL: https://dal.objectstorage.open.softlayer.com/v1/AUTH_cdbef52bdf7a449c96936e1071f0a46b/setiCompAmp/2014-05-25/act15745/2014-05-25_12-48-25_UTC.act15745.dx2009.id-1.R.archive-compamp?temp_url_sig=0a08708fb23834b45e03bee6a2beaf4f8cd4c1ac&temp_url_expires=1493591875
# file size:  1061928

# %%
print r.json()['license_notification']
# Out:
# This data is licensed by the SETI Institute under the Creative Commons BY 4.0 license.  https://github.com/ibm-cds-labs/seti_at_ibm/blob/master/setigopublic.md#data-license
